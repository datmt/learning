# %%
# Fine tuning

# %%
# !pip3 install datasets
# !pip install tf-keras
# !pip install 'accelerate>=0.26.0'
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: datasets in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (4.6.1)
# Requirement already satisfied: filelock in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (3.20.1)
# Requirement already satisfied: numpy>=1.17 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (0.27.2)
# Requirement already satisfied: tqdm>=4.66.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2025.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: sniffio in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: tf-keras in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.2)
# Requirement already satisfied: namex in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10.2)
# Requirement already satisfied: pillow in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting accelerate>=0.26.0
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (25.0)
# Requirement already satisfied: psutil in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (7.2.2)
# Requirement already satisfied: pyyaml in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (2.9.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from accelerate>=0.26.0) (0.7.0)
# Requirement already satisfied: filelock in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2025.12.0)
# Requirement already satisfied: requests in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=0.26.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate>=0.26.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2025.11.12)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 3.0 MB/s eta 0:00:002.5 MB/s eta 0:00:01
# Installing collected packages: accelerate
# Successfully installed accelerate-1.13.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
"""
Complete Fine-Tuning Script for Text Classification
Train DistilBERT on IMDB sentiment analysis with full tracking and visualization
"""

import torch
import numpy as np
from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
import matplotlib.pyplot as plt
import os


def check_gpu():
    """Verify GPU availability and display info."""
    print("="*70)
    print("SYSTEM CHECK")
    print("="*70)
    print(f"PyTorch version: {torch.__version__}")
    print(f"CUDA available: {torch.cuda.is_available()}")
    
    if torch.cuda.is_available():
        print(f"CUDA version: {torch.version.cuda}")
        print(f"GPU: {torch.cuda.get_device_name(0)}")
        print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    else:
        print("WARNING: No GPU detected. Training will be slower on CPU.")
    
    print("="*70 + "\n")


def load_and_explore_data(sample_size=None):
    """Load IMDB dataset and show statistics."""
    print("="*70)
    print("LOADING DATA")
    print("="*70)
    
    # Load full dataset
    dataset = load_dataset("imdb")
    
    print(f"Full dataset loaded:")
    print(f"  Training examples: {len(dataset['train']):,}")
    print(f"  Test examples: {len(dataset['test']):,}")
    
    # Create smaller subset if specified
    if sample_size:
        train_dataset = dataset['train'].shuffle(seed=42).select(range(sample_size))
        test_dataset = dataset['test'].shuffle(seed=42).select(range(sample_size // 5))
        print(f"\nUsing subset for faster training:")
        print(f"  Training: {len(train_dataset):,} examples")
        print(f"  Test: {len(test_dataset):,} examples")
    else:
        train_dataset = dataset['train']
        test_dataset = dataset['test']
    
    # Show examples
    print(f"\nExample reviews:")
    for i in range(2):
        label = "Positive" if train_dataset[i]['label'] == 1 else "Negative"
        print(f"\n  Example {i+1} ({label}):")
        print(f"  {train_dataset[i]['text'][:200]}...")
    
    # Statistics
    labels = [example['label'] for example in train_dataset]
    print(f"\nLabel distribution:")
    print(f"  Negative (0): {labels.count(0):,} ({labels.count(0)/len(labels)*100:.1f}%)")
    print(f"  Positive (1): {labels.count(1):,} ({labels.count(1)/len(labels)*100:.1f}%)")
    
    print("="*70 + "\n")
    
    return train_dataset, test_dataset


def prepare_tokenizer_and_data(train_dataset, test_dataset, model_name="distilbert-base-uncased"):
    """Tokenize datasets."""
    print("="*70)
    print("TOKENIZATION")
    print("="*70)
    
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    print(f"Tokenizer: {model_name}")
    print(f"Vocabulary size: {tokenizer.vocab_size:,}")
    print(f"Max length: {tokenizer.model_max_length}")
    
    # Example tokenization
    example_text = train_dataset[0]['text'][:100]
    tokens = tokenizer.tokenize(example_text)
    token_ids = tokenizer.convert_tokens_to_ids(tokens)
    
    print(f"\nExample tokenization:")
    print(f"  Text: {example_text}...")
    print(f"  Tokens: {tokens[:10]}...")
    print(f"  Token IDs: {token_ids[:10]}...")
    print(f"  Number of tokens: {len(tokens)}")
    
    # Tokenize datasets
    def tokenize_function(examples):
        return tokenizer(
            examples['text'],
            padding='max_length',
            truncation=True,
            max_length=512
        )
    
    print(f"\nTokenizing datasets...")
    tokenized_train = train_dataset.map(tokenize_function, batched=True)
    tokenized_test = test_dataset.map(tokenize_function, batched=True)
    
    # Set format for PyTorch
    tokenized_train.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
    tokenized_test.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
    
    print(f"Tokenization complete!")
    print("="*70 + "\n")
    
    return tokenizer, tokenized_train, tokenized_test


def create_model(model_name="distilbert-base-uncased", num_labels=2):
    """Load pre-trained model and display architecture."""
    print("="*70)
    print("MODEL SETUP")
    print("="*70)
    
    # Load model
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name,
        num_labels=num_labels
    )
    
    # Move to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    
    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    print(f"Model: {model_name}")
    print(f"Device: {device}")
    print(f"Total parameters: {total_params:,}")
    print(f"Trainable parameters: {trainable_params:,}")
    print(f"Model size: ~{total_params * 4 / 1024**2:.1f} MB")
    
    print("="*70 + "\n")
    
    return model, device


def compute_metrics(eval_pred):
    """Compute accuracy, precision, recall, F1."""
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    
    accuracy = (predictions == labels).mean()
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary'
    )
    
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }


def train_model(model, tokenized_train, tokenized_test, output_dir="./results"):
    """Train the model with progress tracking."""
    print("="*70)
    print("TRAINING")
    print("="*70)
    
    # Training arguments
    training_args = TrainingArguments(
        output_dir=output_dir,
        
        # Training parameters
        num_train_epochs=3,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=32,
        learning_rate=2e-5,
        
        # Optimization
        warmup_steps=100,
        weight_decay=0.01,
        
        # Evaluation and logging
        eval_strategy="steps",
        eval_steps=100,
        logging_dir='./logs',
        logging_steps=50,
        save_strategy="steps",
        save_steps=100,
        
        # Best model
        load_best_model_at_end=True,
        metric_for_best_model="accuracy",
        
        # Performance
        fp16=torch.cuda.is_available(),  # Use mixed precision if GPU available
        
        seed=42
    )
    
    print(f"Training configuration:")
    print(f"  Epochs: {training_args.num_train_epochs}")
    print(f"  Batch size: {training_args.per_device_train_batch_size}")
    print(f"  Learning rate: {training_args.learning_rate}")
    print(f"  Mixed precision (fp16): {training_args.fp16}")
    
    total_steps = len(tokenized_train) // training_args.per_device_train_batch_size * training_args.num_train_epochs
    print(f"  Total training steps: {total_steps:,}")
    
    # Create trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_train,
        eval_dataset=tokenized_test,
        compute_metrics=compute_metrics
    )
    
    print(f"\nStarting training...")
    print("="*70)
    
    # Train
    train_result = trainer.train()
    
    print("\n" + "="*70)
    print("TRAINING COMPLETE")
    print("="*70)
    print(f"Training time: {train_result.metrics['train_runtime']:.2f} seconds")
    print(f"Training samples/second: {train_result.metrics['train_samples_per_second']:.2f}")
    print("="*70 + "\n")
    
    return trainer


def evaluate_model(trainer, tokenizer, device):
    """Evaluate model and show detailed results."""
    print("="*70)
    print("EVALUATION")
    print("="*70)
    
    # Evaluate on test set
    eval_results = trainer.evaluate()
    
    print(f"Test Set Performance:")
    print(f"  Accuracy:  {eval_results['eval_accuracy']:.4f}")
    print(f"  Precision: {eval_results['eval_precision']:.4f}")
    print(f"  Recall:    {eval_results['eval_recall']:.4f}")
    print(f"  F1 Score:  {eval_results['eval_f1']:.4f}")
    print(f"  Loss:      {eval_results['eval_loss']:.4f}")
    
    # Test on custom examples
    print(f"\n" + "-"*70)
    print("Testing on custom examples:")
    print("-"*70)
    
    test_examples = [
        "This movie was absolutely amazing! Best film I've seen all year.",
        "Terrible movie. Complete waste of time and money.",
        "It was okay, nothing special but not terrible either.",
        "Incredible performances and stunning cinematography!",
        "Boring plot, bad acting, very disappointed."
    ]
    
    model = trainer.model
    model.eval()
    
    for text in test_examples:
        encoded = tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)
        
        with torch.no_grad():
            outputs = model(**encoded)
            probs = torch.softmax(outputs.logits, dim=1)
            prediction = torch.argmax(probs, dim=1)
        
        sentiment = "Positive ✓" if prediction.item() == 1 else "Negative ✗"
        confidence = probs[0][prediction.item()].item()
        
        print(f"\nText: {text}")
        print(f"Prediction: {sentiment} (confidence: {confidence:.1%})")
    
    print("="*70 + "\n")
    
    return eval_results


def create_visualizations(trainer, save_dir="./visualizations"):
    """Create and save training visualizations."""
    print("="*70)
    print("CREATING VISUALIZATIONS")
    print("="*70)
    
    os.makedirs(save_dir, exist_ok=True)
    
    # Get predictions
    predictions = trainer.predict(trainer.eval_dataset)
    pred_labels = np.argmax(predictions.predictions, axis=-1)
    true_labels = predictions.label_ids
    
    # Confusion Matrix
    cm = confusion_matrix(true_labels, pred_labels)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap='Blues')
    plt.title('Confusion Matrix - Sentiment Classification', fontsize=14, pad=20)
    plt.colorbar()
    
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ['Negative', 'Positive'])
    plt.yticks(tick_marks, ['Negative', 'Positive'])
    
    # Add text annotations
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black",
                    fontsize=16)
    
    plt.ylabel('True Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.tight_layout()
    
    cm_path = os.path.join(save_dir, 'confusion_matrix.png')
    plt.savefig(cm_path, dpi=300, bbox_inches='tight')
    print(f"✓ Confusion matrix saved to: {cm_path}")
    plt.close()
    
    # Prediction confidence distribution
    probs = torch.softmax(torch.tensor(predictions.predictions), dim=1)
    confidences = probs.max(dim=1).values.numpy()
    
    plt.figure(figsize=(10, 6))
    plt.hist(confidences, bins=50, edgecolor='black', alpha=0.7)
    plt.xlabel('Prediction Confidence', fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.title('Distribution of Prediction Confidences', fontsize=14, pad=20)
    plt.axvline(confidences.mean(), color='red', linestyle='--', 
                label=f'Mean: {confidences.mean():.3f}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    
    conf_path = os.path.join(save_dir, 'confidence_distribution.png')
    plt.savefig(conf_path, dpi=300, bbox_inches='tight')
    print(f"✓ Confidence distribution saved to: {conf_path}")
    plt.close()
    
    print("="*70 + "\n")


def save_model(trainer, tokenizer, save_dir="./my_finetuned_model"):
    """Save the fine-tuned model and tokenizer."""
    print("="*70)
    print("SAVING MODEL")
    print("="*70)
    
    # Save model and tokenizer
    trainer.model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)
    
    print(f"Model and tokenizer saved to: {save_dir}")
    print(f"Files saved:")
    for file in os.listdir(save_dir):
        print(f"  - {file}")
    
    print("\nTo load later:")
    print(f"  from transformers import AutoModelForSequenceClassification, AutoTokenizer")
    print(f"  model = AutoModelForSequenceClassification.from_pretrained('{save_dir}')")
    print(f"  tokenizer = AutoTokenizer.from_pretrained('{save_dir}')")
    
    print("="*70 + "\n")


def main(sample_size=1000):
    """
    Complete fine-tuning pipeline.
    
    Args:
        sample_size: Number of training examples to use (None for full dataset)
                    Recommended: 1000 for quick testing, None for best performance
    """
    print("\n" + "="*70)
    print("FINE-TUNING DISTILBERT FOR SENTIMENT ANALYSIS")
    print("="*70 + "\n")
    
    # Check system
    check_gpu()
    
    # Load data
    train_dataset, test_dataset = load_and_explore_data(sample_size=sample_size)
    
    # Tokenize
    tokenizer, tokenized_train, tokenized_test = prepare_tokenizer_and_data(
        train_dataset, test_dataset
    )
    
    # Create model
    model, device = create_model()
    
    # Train
    trainer = train_model(model, tokenized_train, tokenized_test)
    
    # Evaluate
    eval_results = evaluate_model(trainer, tokenizer, device)
    
    # Visualize
    create_visualizations(trainer)
    
    # Save
    save_model(trainer, tokenizer)
    
    print("="*70)
    print("ALL DONE!")
    print("="*70)
    print(f"\nFinal Accuracy: {eval_results['eval_accuracy']:.2%}")
    print("\nNext steps:")
    print("  1. Try the full dataset: main(sample_size=None)")
    print("  2. Experiment with different hyperparameters")
    print("  3. Try a different dataset (AG News, SST-2)")
    print("  4. Move on to Project 3: Attention mechanism")
    print("="*70 + "\n")


if __name__ == "__main__":
    # Run with small sample for quick testing
    # Change to main(sample_size=None) to use full dataset
    main(sample_size=1000)
# Out:
# 2026-03-08 21:12:40.071424: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-08 21:12:40.101415: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-08 21:12:41.061598: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ======================================================================
# FINE-TUNING DISTILBERT FOR SENTIMENT ANALYSIS
# ======================================================================
#
# ======================================================================
# SYSTEM CHECK
# ======================================================================
# PyTorch version: 2.9.1+cu128
# CUDA available: False
# WARNING: No GPU detected. Training will be slower on CPU.
# ======================================================================
#
# ======================================================================
# LOADING DATA
# ======================================================================
# Full dataset loaded:
#   Training examples: 25,000
#   Test examples: 25,000
#
# Using subset for faster training:
#   Training: 1,000 examples
#   Test: 200 examples
#
# Example reviews:
#
#   Example 1 (Positive):
#   There is no relation at all between Fortier and Profiler but the fact that both are police series about violent crimes. Profiler looks crispy, Fortier looks classic. Profiler plots are quite simple. F...
#
#   Example 2 (Positive):
#   This movie is a great. The plot is very true to the book which is a classic written by Mark Twain. The movie starts of with a scene where Hank sings a song with a bunch of kids called "when you stub y...
#
# Label distribution:
#   Negative (0): 512 (51.2%)
#   Positive (1): 488 (48.8%)
# ======================================================================
#
# ======================================================================
# TOKENIZATION
# ======================================================================
# Tokenizer: distilbert-base-uncased
# Vocabulary size: 30,522
# Max length: 512
#
# Example tokenization:
#   Text: There is no relation at all between Fortier and Profiler but the fact that both are police series ab...
#   Tokens: ['there', 'is', 'no', 'relation', 'at', 'all', 'between', 'fort', '##ier', 'and']...
#   Token IDs: [2045, 2003, 2053, 7189, 2012, 2035, 2090, 3481, 3771, 1998]...
#   Number of tokens: 21
#
# Tokenizing datasets...
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Tokenization complete!
# ======================================================================
#
# ======================================================================
# MODEL SETUP
# ======================================================================
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: distilbert-base-uncased
# Device: cpu
# Total parameters: 66,955,010
# Trainable parameters: 66,955,010
# Model size: ~255.4 MB
# ======================================================================
#
# ======================================================================
# TRAINING
# ======================================================================
# Training configuration:
#   Epochs: 3
#   Batch size: 16
#   Learning rate: 2e-05
#   Mixed precision (fp16): False
#   Total training steps: 186
#
# Starting training...
# ======================================================================
# /home/dat/.pyenv/versions/3.11.9/lib/python3.11/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='8' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  8/189 00:45 < 22:37, 0.13 it/s, Epoch 0.11/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
